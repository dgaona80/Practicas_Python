# %% [markdown]
# # APRENDE PYTHON DE CERO A: YA SABES
# ## David Daniel GL
# ### 29 Julio 2024

# %%
#Comentarios dentro del código
print("Bienvenido al curso de Python para principiantes")
# Out:
# Bienvenido al curso de Python para principiantes

# %%
print("****************************************************")
print("Bienvenido al curso de Python para Principiantes")
print("***************************************************")
# Out:
# ****************************************************
# Bienvenido al curso de Python para Principiantes
# ***************************************************

# %%
print("Hola amigos")
print('Hola "amigos"')
print("hola" + "amigos")
print("hola" + " amigos")
print("Hola"+"amigos")
print("hola","amigos")
# Out:
# Hola amigos
# Hola "amigos"
# holaamigos
# hola amigos
# Holaamigos
# hola amigos

# %%
# En evaluación si se pone
word = 'World'
print(f'Hello,  {word}')
# Out:
# Hello,  World

# %% [markdown]
# ## TIPOS DE DATOS

# %%
type(2)   #int
# Out:
# int

# %%
type(1.89)
# Out:
# float

# %%
type("Bienvenido al curso")  #string
# Out:
# str

# %%
type(True) # bool
# Out:
# bool

# %% [markdown]
# ## Operaciones con variables numéricas

# %%
var_suma = 2+5
print(var_suma)
# Out:
# 7

# %%
print("Resultado de la suma de 5 + 7= ",var_suma)
print(f'Resultado de la suma de 5 + 7=, {var_suma}')
# Out:
# Resultado de la suma de 5 + 7=  7
# Resultado de la suma de 5 + 7=, 7

# %% [markdown]
# ## Operaciones con variables de texto

# %%
palabra ="Millicom"
print(palabra)
print(palabra[0])
print(palabra[5])
print(palabra[1:3])
print(palabra+"M")
print(2*palabra)
# Out:
# Millicom
# M
# c
# il
# MillicomM
# MillicomMillicom

# %%
print("-------OPERACIONES DE ASIGNACION -------------------- ")

A=2+2
print(A)
A+=2
print(A)
A-=1
print(A)
A*=2
print(A)
A=A**2 #POTENCIA
print(A)
A/=3
print(A)
A//=2 #DIVISIÓN ENTERA
print(A)
#A=3
#A%=2 #SE LE ASIGNA LO QUE YA TIENE %2
#print(A)
# Out:
# -------OPERACIONES DE ASIGNACION --------------------
# 4
# 6
# 5
# 10
# 100
# 33.333333333333336
# 16.0

# %%
# Formato de números separar en miles
x = 1000
print(f'{x:,}')

x = 500 / 13
print(x)
print(f'{x:.3f}')
# Out:
# 1,000
# 38.46153846153846
# 38.462

# %% [markdown]
# # Actividades 30 julio 2024

# %%
#Actividad 1 

#Potencia
A=7

A**=3

print(A)
# Out:
# 343

# %% [markdown]
# #Actividad 2
#
# # Ejemplos prácticos

# %%
# 1 convertir de km kilómetros a millas

#1 milla->0.621371 km
var_milla=0.621371

#1 km -> 1.609 millas
var_kilometro=1.609

print("-------------EJEMPLOS DE CONVERSIÓN-------------------")
print("-----------------KM A MILLAS--------------------------")
print("  ")
var_conv=var_milla*5
print(f' 5 km equivalen a: {var_conv} millas')
print(f' 5 km equivalen a: {var_milla*5} millas')
print(f' 5 km equivalen a: {var_milla*5:.2f} millas')
print(f' 12 km equivalen a: {var_milla*12:.2f} millas')
print("  ")
print("-----------------MILLAS A KM--------------------------")
print("  ")
print(f' 5 millas equivalen a: {var_kilometro*5:.2f} kilómetros')
print(f' 100 millas equivalen a: {var_kilometro*100:.2f} kilómetros')
print(f' 370 millas equivalen a: {var_kilometro*370:.2f} kilómetros')
# Out:
# -------------EJEMPLOS DE CONVERSIÓN-------------------
# -----------------KM A MILLAS--------------------------
#
#  5 km equivalen a: 3.106855 millas
#  5 km equivalen a: 3.106855 millas
#  5 km equivalen a: 3.11 millas
#  12 km equivalen a: 7.46 millas
#
# -----------------MILLAS A KM--------------------------
#
#  5 millas equivalen a: 8.04 kilómetros
#  100 millas equivalen a: 160.90 kilómetros
#  370 millas equivalen a: 595.33 kilómetros

# %% [markdown]
# ---

# %% [markdown]
# # Ejercicio en clase
# Tipo de cambio 30 jul
#
# 1 USD:  0.9246 EUR
# 1 EUR:  1.0815 USD
# 1 USD: $18.7628 MXN
# 1 EUR: $20.2898 MXN
#
# Precio del paquete: $3,165 USD
#
# ¿Cuánto me costará en MXN?
# ¿Cuanto me costará en EUR?

# %%
# Solución

var_CostoUSD=3165
var_Tc_MXN_USD=18.7628
var_Tc_MXN_EUR=20.2898
var_Tc_EUR_USD=1.0815
var_Tc_USD_EUR=0.9246

print("------Mi viaje a EUROPA----")
print(" ")
print("Costo del viaje: 3,165 USD")
print(" ")
print(" ")
var_Precio_MXN=var_CostoUSD*var_Tc_MXN_USD
var_Precio_EUR=var_CostoUSD*var_Tc_USD_EUR
var_Precio_MXN_EUR=var_Precio_EUR*var_Tc_MXN_EUR

print(f'Precio en MXN:     ${var_Precio_MXN:,.2f}')
print(f'Precio en EUR:       {var_Precio_EUR:,.2f}' )
print(f'Precio en MXN-EUR: ${var_Precio_MXN_EUR:,.2f}')
# Out:
# ------Mi viaje a EUROPA----
#
# Costo del viaje: 3,165 USD
#
#
# Precio en MXN:     $59,384.26
# Precio en EUR:       2,926.36
# Precio en MXN-EUR: $59,375.24

# %%
#Actividad 3 
print("-------OPERACIONES RELACIONALES-------------------- ")
print("        == != > < >= <=                             ")

A=10
B=20

print("  ")
print(f'valor de la variable A: {A}, valor de la variable B: {B}')
print("  ")
print(A==B)
print(A!=B)
print(A>=B)
print(A<=B)
print(A>B)
print(A<B)
print(f"{A} es igual a {B} : {A==B}")
print(f"{A}=={B} es {A==B}")
print(f"{A}!={B} es {A!=B}")
print(f"{A}>={B} es {A>=B}")
print(f"{A}<={B} es {A<=B}")
print(f"{A}>{B} es {A>B}")
print(f"{A}<{B} es {A<B}")

n1 = 7
n2 = 9
print(f'{n1} es menor que: {n2}? {n1<n2}')
# Out:
# -------OPERACIONES RELACIONALES--------------------
#         == != > < >= <=
#
# valor de la variable A: 10, valor de la variable B: 20
#
# False
# True
# False
# True
# False
# True
# 10 es igual a 20 : False
# 10==20 es False
# 10!=20 es True
# 10>=20 es False
# 10<=20 es True
# 10>20 es False
# 10<20 es True
# 7 es menor que: 9? True

# %% [markdown]
# <img src="encabezado.png" alt="Curso Python" width="200" height="100" align="left"> **Autor:**

# %% [markdown]
# \# Actividad 4
# <img src="encabezado.png" alt="Curso Python" width="200" height="100"
#     align="right" title="Bienvenid@">
#
# # Bienvenido

# %% [markdown]
# **<span style="color:red">Hola</span>**

# %% [markdown]
# <img src="encabezado.png" alt="Curso Python" width="200" height="100" align="left"> **TITULO**
#
# # **TITULO**
#
# ### 28 julio 2024
#
# **Texto Negrita**
#
# __texto negrita2__
#
# texto normal
#
# *Texto cursiva*
#
# _texto cursiva2_
#
# ***Texto Negrita***
#
# ___texto negrita2___
#
# ~~subrayado~~
#
# \# No encabezado
#
# > prueba
# > > prueba prueba
# > > >mas pruebas
#
# ---
# ___
# ***
#
# 1. a
# 2. b
# 3. c
#
# - pan
# - leche
# - huevo

# %% [markdown]
# ***comentarios***

# %% [markdown]
# <img src=http://animals.sandiegozoo.org/sites/default/
#     files/2016-09/animals_hero_armadillo_0.jpg>

# %%
# import image module 
from IPython.display import Image 

# get the image 
Image(url="encabezado.png", width=300, height=500)
# Out:
# <img src="encabezado.png" width="300" height="500"/>

# %% [markdown]
# ![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)

# %% [markdown]
# ![][some-id]
#
# [some-id]: https://www.python.org/static/community_logos/python-logo-master-v3-TM.png "Python Logo"

# %%
![][some-id]

[some-id]: encabezado.png
# Out:
#   Cell In[217], line 3
#     [some-id]: encabezado.png
#     ^
# SyntaxError: only single target (not list) can be annotated

# %% [markdown]
# # Lista de tareas

# %% [markdown]
# - [x] Tarea 1
# - [ ] Tarea 2

# %%
#Nivel de precedencia:

a = 10 * 5 + 2 / (8 + 2)
print(a)

# %% [markdown]
# ## Estructura de Datos: Listas y Tuplas

# %%
# Ejemplo de tupla 1

tupla_1=('Norte','Sur','Este','Oeste')
print(tupla_1)
print(tupla_1[0])
print(tupla_1[1:3])
print(tupla_1[-1])
type(tupla_1)

# %%
# Ejemplo de tupla 2

tupla_2=('Rojo',1,'Azul',2,'Amarillo',3.1)
print(tupla_2)
print(tupla_2[1])
print(tupla_2[2:5])
print(tupla_2[-1])
type(tupla_2)

# %%
# Ejemplo de listas 1

Lst_Total_Medallas=['EEUU',26,'Francia',18,'China',14]
print(Lst_Total_Medallas)
type(Lst_Total_Medallas)
Lst_Total_Medallas[0]

# %%
# Partición de listas
Lst_Total_Medallas[:3]

# %%
# Partición de listas
Lst_Total_Medallas[2:]

# %%
# Ejemplo de listas 2

# %%
#Ejercicio grupal de listas

# %%
Lst_Total_Medallas2=[['Japón','Oro',7],['China','Oro',6],['EEUU','Plata',11],['Francia','Plata',9]]


type(Lst_Total_Medallas2)
print(Lst_Total_Medallas2[0][0])
print(Lst_Total_Medallas2[1][0])
print(Lst_Total_Medallas2[2][0])
print(Lst_Total_Medallas2[3][0])
#print(Lst_Total_Medallas2[4][0])
#print(Lst_Total_Medallas2[0][4])

# %%
print(Lst_Total_Medallas2[0][1])
print(Lst_Total_Medallas2[1][1])
print(Lst_Total_Medallas2[2][1])
print(Lst_Total_Medallas2[3][1])

# %%
print(Lst_Total_Medallas2[0][2])
print(Lst_Total_Medallas2[1][2])
print(Lst_Total_Medallas2[2][2])
print(Lst_Total_Medallas2[3][2])

# %%
# lementos de la lista
len(Lst_Total_Medallas2)

# %%
# lementos de la segunda lista
len(Lst_Total_Medallas2[0])

# %%
#Agregar elementos a una lista

Lst_Total_Medallas3=[['China','Plata',6]]

print(Lst_Total_Medallas3)

# %%
#Agregar
Lst_Total_Medallas2=Lst_Total_Medallas2+Lst_Total_Medallas3
print(Lst_Total_Medallas2)

# %%
# tamaño lista
len(Lst_Total_Medallas2)

# %%
print(Lst_Total_Medallas2[4])

# %%
del(Lst_Total_Medallas2[4])

# %%
print(Lst_Total_Medallas2)

# %%
print(Lst_Total_Medallas2[1][2])

# %%
# Cambiar valores de una lista
Lst_Total_Medallas2[1][2]=7

# %%
# Agregar elementos a una lista, ordernar y reverse
lista_4=['Blanco','Negro']
print(lista_4)
lista_4.append('gris')
print(lista_4)
lista_4.append('rojo')
print(lista_4)
print(lista_4.pop(3))
print(lista_4)
lista_4.sort()
print(lista_4)
lista_4[2]='Gris'
print(lista_4)
lista_4.sort()
print(lista_4)
lista_4.reverse() #no es lo opuesto a sort
print(lista_4)

# %% [markdown]
# ## Ejercicio en clase

# %% [markdown]
# https://www.msn.com/es-mx/deportes/olympics/medallas?ocid=msedgntp&cvid=5801da14f71b4a36b4c54396befd85e8&pc=U531&ei=13

# %% [markdown]
# ## Lectura de Datos

# %%
print("-------------------------------------")

print("-----------LECTURA DE DATOS----------")

nombre=input("Hola, ¿Cuál es tu nombre?")
if len(nombre) >1 :
	print(f'Mucho gusto, {nombre}')
else:
    print("No capturaste información :(")


nombre=input("¿Cómo te dicen?")
if len(nombre) >1 :
	print(f'jajaja,es muy chistoso {nombre}')
else:
    print("No capturaste información :(")


#nombre=input("¿cómo te llamas?")
#print(f"Me alegro de conocerte,{nombre}")

# %%
print("-----------LECTURA DE DATOS----------")
print(" ")
nombre=input("Hola, ¿Cuál es tu nombre?")
#nombre=nombre.strip()
nombre=nombre.strip('., ')
if (len(nombre) > 1):
	print(f'Mucho gusto, {nombre}')
else:
    print("No capturaste suficiente información :(")


nombre=input("¿Cómo te dicen?")
#print(len(nombre))
nombre=nombre.strip('., ')
#print(f'nombre limpiando espacios: {nombre} {len(nombre)}')
if (len(nombre) >1):
	print(f' mmm... suena raro... {nombre}')
else:
    print("No capturaste suficiente información :(")

# %% [markdown]
# ## uso de replace

# %%
var_dir_cte=input("Escribe la dirección del cliente")
#var_dir_cte_dq=var_dir_cte.upper().replace('#','NUM. ')
var_dir_cte_dq=var_dir_cte.replace('#','NUM. ').upper().strip()
print(var_dir_cte_dq)

if len(var_dir_cte)!=len(var_dir_cte_dq):
    print(f'Se realizó un proceso de limpieza de datos: {var_dir_cte_dq}')
else:
    print(f'No hubo limpieza de datos.')
    print('ok')

# %%
# COUNT - cuenta las veces que encuentra el caracter o cadena espeficada

var_palabra='Olimpiadas 2024'
print(var_palabra.count('i'))

var_palabra2='Tres tristes tigres, tragaban trigo en un trigal, en tres tristes trastos.'
print(var_palabra2.count('Tres'))
var_palabra2=var_palabra2.lower()
print(var_palabra2)
print(var_palabra2.count('tres'))
print(var_palabra2.count('tr'))
print(var_palabra2.upper())

# %%
#FORMAS DE OBTENER UN SUBSTRING


var_palabra2='Tres tristes tigres, tragaban trigo en un trigal, en tres tristes trastos.'

#DEL INICIO HASTA EL INDICE INDICADO
var_substring=var_palabra2[:26]
print(var_substring)

#POR RANGO DE INDICES
var_substring2=var_palabra2[5:30]
print(var_substring2)

#POR ÍNDICE ESPECIFICADO EN EL MÉTODO INDEX
indice_cadena=var_palabra2.index('i')
var_substring3=var_palabra2[:indice_cadena]
print(var_substring3)

#Por índice donde empieza la palabra a buscar:
var_palabra2='tres tristes tigres, tragaban trigo en un trigal, en tres tristes trastos.'
print('Cadena de texto completa:\n', var_palabra2)
palabra_buscar=input("Escribe la palabra que deseas buscar:")
print(" ")
print('se realizará el substring hasta la palabra:',palabra_buscar)
print(" ")
print(f'Índice donde se encuentra la palabra:{palabra_buscar}: ',var_palabra2.find('trigo'))
print(" ")
print(f'Substring generado antes de la palabra a buscar: ',var_palabra2[0:var_palabra2.find('trigo')])
print(" ")
print(f'Substring generado después de la palabra a buscar: ',var_palabra2[var_palabra2.find('trigo'):])

# %%
#Metodos de String




#Actualización:
# Versión 2 -- valida que la palabra a buscar sí exista en la cadena
var_palabra2='tres tristes tigres, tragaban trigo en un trigal, en tres tristes trastos.'
print('Cadena de texto completa:\n', var_palabra2)
print(" ")
print(" ")
palabra_buscar=input("Escribe la palabra que deseas buscar:")
print(" ")

if palabra_buscar in var_palabra2:
    print('se realizará el substring hasta la palabra:',palabra_buscar)
    print(" ")
    print(f'Índice donde se encuentra la palabra:{palabra_buscar}: ',var_palabra2.find(palabra_buscar))
    print(" ")
    print(f'Substring generado antes de la palabra a buscar: ',var_palabra2[0:var_palabra2.find(palabra_buscar)])
    print(" ")
    print(f'Substring generado después de la palabra a buscar: ',var_palabra2[var_palabra2.find(palabra_buscar):])
else:
    print('¡Captura incorrecta, adiós!')

# %%
#split()  join()

#split() .- dividir una cadena en subcadenas
var_palabra="Yo me despierto a las 5 de la mañana"
print(var_palabra.split())
var_palabra2="Yo me despierto sin ganas, a las 5 de la mañana"
print(var_palabra2.split(','))
print(" ")
var_palabra3="lunes|martes|miercoles|jueves|viernes"
print(var_palabra3.split('|'))

print(var_palabra3.split('|',3)) #maxsplit

# %%
# Del Split al join
Lista_dias=[]
var_palabra3="lunes|martes|miercoles|jueves|viernes"
Lista_dias=var_palabra3.split('|')
print(Lista_dias)
var_palabra_join=','.join(Lista_dias)
print(var_palabra_join)

# %% [markdown]
# ## EJERCICIOS día 4

# %%
# Capitalize & str.title() 
Var_Nombre_Cliente=input("Escribre el nombre del cliente: ".capitalize())

print(Var_Nombre_Cliente.capitalize())

print(Var_Nombre_Cliente.title())
#Var_Nombre_Cliente=Var_Nombre_Cliente.capitalze()

# %%
## Uso de BUCLES

# los Bucles / Loops en Python pueden iterar(recorrer) a lo largo de cualquier secuencia (listas, strings)
# Se ejecuta las secuencias de código tantas veces siempre y cuando se cumpla una cierta condición

#Ejemplo bucle while

contador = 0
while contador < 5:
   print("El contador es: ", contador)
   contador += 1

# %%
contador = 0
while contador < 5:
   print("Hola", contador)
   contador += 1

# %%
cont=0

print(Lista_dias[2])
print(f'total de elementos en la lista:',len(Lista_dias))

while cont<len(Lista_dias):
    print(Lista_dias[cont])
    cont+=1

# %%
# Cliclo For

for d in Lista_dias:
    print(d)

# %%
for d in Lista_dias:
    print(d)
    if d=='jueves':
        print(f' {d}=jueves: {d=='jueves'} -> salir del bucle')
        break
    else:
        print(f' {d} <> jueves, continúa el bucle')

# %%
for i in range(5):
    print(i)

# %%
valores = {'A': 4, 'E': 3, 'I': 1, 'O': 0}
for clave, valor in valores.items():
    print(f"Clave: {clave}, Valor: {valor}")

# %%
#funación range
list(range(2,20,10))

# %%
#Tablas del 7
numero = 7
for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")

# %%
for i in range(10, 15, 2):
    print(i)

# %%
for i in range(1, 30+3, 3):
    print(i)

# %%
#order decreciente
for i in range(20, -1, -5):
    print(i)

# %% [markdown]
# ## Lectura de archivos

# %%
#lectura de archivo
var_archivo1='Archivo1.txt'
leer_archivo=open(var_archivo1,"r")
print(leer_archivo)

# %%
#leer el archivo en modo lectura
leer_archivo=open(var_archivo1,"r")

# %%
#lee una línea de texto
print(leer_archivo.readline())
print(leer_archivo.readline())

# %%
#lee  líneas de texto -- devuelve los elementos como una lista
print(leer_archivo.readlines())

# %%
print(leer_archivo.read())

# %%
#cerrar el archivo
leer_archivo.close()

# %%
#Escribir el archivo:
escribir_archivo=open(var_archivo1,"w")

# %%
#crear una lista de valores para insertar
lst_valores_archivo=['Y ahora\n','ya pude\n','escribir\n','en el archivo\n']

# %%
escribir_archivo.writelines(lst_valores_archivo)

# %%
escribir_archivo.write('Adiós\n')

# %%
escribir_archivo.close()

# %%
#generar un error
print(escribir_archivo.read())

# %%
## Ejercicio en clase - tarea W+ R+

# %% [markdown]
# ---

# %% [markdown]
# ## DIA 5: Manejar el puntero

# %%
## DIA 5: Manejar el puntero
#abrir el archivo en modo lectura
leer_archivo=open(var_archivo1,"r")

print(leer_archivo.read())

leer_archivo.seek(0) # movemos el puntero al principio

print(leer_archivo.read(10))

leer_archivo.seek(0) # movemos el puntero al principio

print(leer_archivo.read(20))

leer_archivo.close()

# %%
#Agregar línea de texto al archivo

agregar_archivo=open(var_archivo1,"a")

agregar_archivo.write('\nSe agregó una línea más')

agregar_archivo.close()

# %%
# modo agregar y crear archivo
agregar_archivo=open('archivo_nuevo.txt',"a+")

agregar_archivo.write('Se agregó una línea al archivo')

agregar_archivo.close()

# %%
# Abrimos el archivo 2 en modo escritura

#Creamos el archivo
var_Archivo2="Archivo2.txt"
#crear_archivo=open(var_Archivo2,"x")
#crear_archivo.close()

#escribir_archivo=open(var_Archivo2,"w")
#var_texto="Otra\nPrueba\Más\nDe escritura"
#escribir_archivo.writelines(var_texto)
#escribir_archivo.close()

# %%
## leer el archivo 1 y luego edigar una linea paso 1
leer_archivo=open(var_archivo1,"r+")
lista_archivo=leer_archivo.readlines()
print(lista_archivo)

# %%
print(lista_archivo[1])

# %%
#editar el valor de la lista
lista_archivo[1]='Logré\n'

# %%
#mostrar lo que se va a reemplazar
print(lista_archivo)

# %%
#nos colocamos al principio
leer_archivo.seek(0)
leer_archivo.writelines(lista_archivo)

leer_archivo.seek(0)
leer_archivo.read()

# %%
leer_archivo.close()

# %%
#crear un nuevo archivo
nuevo_archivo=open("nuevo_archivo.txt","x")
nuevo_archivo.close()

# %%
#Usar el With y el ciclo for

Archivo1='Archivo1.txt'

with open(Archivo1,"r") as leer_archivo:
    for linea in leer_archivo: #hace barrido para leer
        print(linea)

leer_archivo.close()

# %% [markdown]
# ---

# %% [markdown]
# ## PANDAS

# %%
#lectura de archivo CSV

# %%
#importar la librería de pandas 
import pandas as pd

# %%
df = pd.read_csv("MEDALLERO_OLIMPICO_2024.csv")

# %%
# cambiar 
df = pd.read_csv("MEDALLERO_OLIMPICO_2024.csv", encoding='latin1')

#df = pd.read_csv("MEDALLERO_OLIMPICO_2024.csv", delimeter=";",encoding='latin1')
#df = pd.read_csv("MEDALLERO_OLIMPICO_2024.csv", delimeter="|",encoding='latin1')

# %%
#mostrar el dataframe
df

# %%
type(df)

# %%
#metadatos
df.info()

# %%
#metadatos

df.describe()

# %%
df.shape

# %%
#nombre de columnas
df.columns

# %%
#hacemos una lista de las columnas
list(df.columns)
#print(list)

# %%
lst_header=list(df.columns)
print(lst_header)

# %%
len(lst_header)

# %%
#error columna nombre
df['oro']

# %%
df['Oro']

# %%
#revisar
#df['Total'].value_counts()

# %%
#unique()

# %%
#Mostrar 2 columnas
df[['País','Total']]

# %%
#condiciones y mostrar las que sean true

var_topOro=(df.Oro >=9)

df[var_topOro]

# %%
#condiciones y mostrar las que sean true

var_topOroPlata = (df.Oro >=9) & (df.Plata >20)

df[var_topOroPlata]

# %%
var_topNorteAmerica = (df.País.isin(['Estados Unidos','México','Canadá']))


df[var_topNorteAmerica]
# Out:
#     num            País  Oro  Plata  Bronce  Total
# 0     1  Estados Unidos   27     35      32     94
# 10   11          Canadá    6      4       9     19
# 55   56          México    0      2       1      3

# %%
#top 10
df.head(10)

# %%
#validar nulos
df.isna()

# %%
#conteo de nulos
df.isna().sum()

# %%
df.Total.min()

# %%
df.Total.max()

# %%
#desviación stándar
df.Total.std()

# %%
#df.groupby(['País','Oro'])['Total'].max()

# %%
import pandas as pd
# Import Excel file

df = pd.read_excel('CLIENTES.xlsx', sheet_name='Hoja1')

# Export to Excel file
df.to_excel('CLIENTES_RESP.xlsx', index=False)

# %% [markdown]
# ## Día 6

# %%
import pandas as pd

# %%
#import pandas as pd

#leer el dataset desde una URL

url='https://raw.githubusercontent.com/dgaona80/Python/main/Paris%202024%20Olympic%20Summer%20Games/medals.csv'

df = pd.read_csv(url)

df.head(10)
# Out:
#      medal_type  medal_code  medal_date             name country_code gender  \
# 0    Gold Medal           1  2024-07-27  Remco EVENEPOEL          BEL      M
# 1  Silver Medal           2  2024-07-27    Filippo GANNA          ITA      M
# 2  Bronze Medal           3  2024-07-27    Wout van AERT          BEL      M
# 3    Gold Medal           1  2024-07-27      Grace BROWN          AUS      W
# 4  Silver Medal           2  2024-07-27   Anna HENDERSON          GBR      W
# 5  Bronze Medal           3  2024-07-27     Chloe DYGERT          USA      W
# 6    Gold Medal           1  2024-07-27            China          CHN      W
# 7  Silver Medal           2  2024-07-27    United States          USA      W
# 8  Bronze Medal           3  2024-07-27    Great Britain          GBR      W
# 9    Gold Medal           1  2024-07-27        OH Sanguk          KOR      M
#
#      discipline                                event event_type  \
# ...

# %%
df.tail(5)
# Out:
#        medal_type  medal_code  medal_date                    name  \
# 686  Bronze Medal           3  2024-08-07       Uzur DZHUZUPBEKOV
# 687    Gold Medal           1  2024-08-07   Sarah Ann HILDEBRANDT
# 688  Silver Medal           2  2024-08-07  Yusneylis GUZMAN LOPEZ
# 689  Bronze Medal           3  2024-08-07              SUSAKI Yui
# 690  Bronze Medal           3  2024-08-07               FENG Ziqi
#
#     country_code gender discipline                   event event_type  \
# 686          KGZ      M  Wrestling  Men's Greco-Roman 97kg       HATH
# 687          USA      W  Wrestling  Women's Freestyle 50kg       HATH
# 688          CUB      W  Wrestling  Women's Freestyle 50kg       HATH
# 689          JPN      W  Wrestling  Women's Freestyle 50kg       HATH
# 690          CHN      W  Wrestling  Women's Freestyle 50kg       HATH
#
#                                              url_event     code
# 686  /en/paris-2024/results/wrestling/men-s-greco-r...  1566601
# ...

# %%
var_MedalUSA = df.sort_values(['country_code'])

#groupby.country_code.medal_type.count()

var_MedalUSA


#df['country_code']
#['temperatura'].sum()

#(df.País.isin(['Estados Unidos','México','Canadá']))
# Out:
#        medal_type  medal_code  medal_date                     name  \
# 352  Silver Medal           2  2024-08-02  Viyaleta BARDZILOUSKAYA
# 348    Gold Medal           1  2024-08-02         Ivan LITVINOVICH
# 512  Silver Medal           2  2024-08-04        ANDREEVA/SHNAIDER
# 403  Silver Medal           2  2024-08-03           Yauheni ZALATY
# 453    Gold Medal           1  2024-08-04            Kaylia NEMOUR
# ..            ...         ...         ...                      ...
# 273    Gold Medal           1  2024-08-01            Kate DOUGLASS
# 309  Bronze Medal           3  2024-08-02          Alisher YUSUPOV
# 250  Bronze Medal           3  2024-08-01    Muzaffarbek TUROBOYEV
# 60     Gold Medal           1  2024-07-28       Diyora KELDIYOROVA
# 632  Bronze Medal           3  2024-08-07         Muzala SAMUKONGA
#
#     country_code gender             discipline                      event  \
# 352          AIN      W  Trampoline Gymnastics                      Women
# ...

# %%
df
# Out:
#        medal_type  medal_code  medal_date                    name  \
# 0      Gold Medal           1  2024-07-27         Remco EVENEPOEL
# 1    Silver Medal           2  2024-07-27           Filippo GANNA
# 2    Bronze Medal           3  2024-07-27           Wout van AERT
# 3      Gold Medal           1  2024-07-27             Grace BROWN
# 4    Silver Medal           2  2024-07-27          Anna HENDERSON
# ..            ...         ...         ...                     ...
# 686  Bronze Medal           3  2024-08-07       Uzur DZHUZUPBEKOV
# 687    Gold Medal           1  2024-08-07   Sarah Ann HILDEBRANDT
# 688  Silver Medal           2  2024-08-07  Yusneylis GUZMAN LOPEZ
# 689  Bronze Medal           3  2024-08-07              SUSAKI Yui
# 690  Bronze Medal           3  2024-08-07               FENG Ziqi
#
#     country_code gender    discipline                          event  \
# 0            BEL      M  Cycling Road    Men's Individual Time Trial
# ...

# %%
total_paises=df.groupby(['country_code'])['medal_type'].count()

total_paises.sort_values(ascending=False, inplace=True)

total_paises

#Totales_paises=list
# Out:
# country_code
# USA    94
# CHN    65
# FRA    51
# GBR    49
# AUS    41
#        ..
# EGY     1
# FIJ     1
# GRN     1
# ALG     1
# ZAM     1
# Name: medal_type, Length: 80, dtype: int64

# %%
total_paises_medallas=df.groupby(['country_code','medal_type'])['medal_code'].count()

#.sort_values(ascending=False)

#total_paises_medallas.sort_values(by=['medal_code'], ascending=False)# , inplace=True)

total_paises_medallas

#Totales_paises=list
# Out:
# country_code  medal_type
# AIN           Gold Medal       1
#               Silver Medal     3
# ALG           Gold Medal       1
# ARG           Gold Medal       1
# ARM           Bronze Medal     1
#                               ..
# USA           Gold Medal      27
#               Silver Medal    35
# UZB           Bronze Medal     2
#               Gold Medal       1
# ZAM           Bronze Medal     1
# Name: medal_code, Length: 165, dtype: int64

# %%
archivo_excel='Sumatoria_Medallas2.xlsx'

total_paises_medallas.to_excel(archivo_excel)

# %%
#agrupación por género
total_medallas_gen=df.groupby(['discipline','medal_type'])['gender'].value_counts()
total_medallas_gen
# Out:
# discipline      medal_type    gender
# 3x3 Basketball  Bronze Medal  M         1
#                               W         1
#                 Gold Medal    M         1
#                               W         1
#                 Silver Medal  M         1
#                                        ..
# Wrestling       Bronze Medal  W         4
#                 Gold Medal    M         4
#                               W         2
#                 Silver Medal  M         4
#                               W         2
# Name: count, Length: 213, dtype: int64

# %%
type(total_paises_medallas)
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['medal_type', 'medal_code', 'medal_date', 'name', 'country_code',
#        'gender', 'discipline', 'event', 'event_type', 'url_event', 'code'],
#       dtype='object')

# %%
#ultimas filas
df.tail(5)
# Out:
#        medal_type  medal_code  medal_date                    name  \
# 686  Bronze Medal           3  2024-08-07       Uzur DZHUZUPBEKOV
# 687    Gold Medal           1  2024-08-07   Sarah Ann HILDEBRANDT
# 688  Silver Medal           2  2024-08-07  Yusneylis GUZMAN LOPEZ
# 689  Bronze Medal           3  2024-08-07              SUSAKI Yui
# 690  Bronze Medal           3  2024-08-07               FENG Ziqi
#
#     country_code gender discipline                   event event_type  \
# 686          KGZ      M  Wrestling  Men's Greco-Roman 97kg       HATH
# 687          USA      W  Wrestling  Women's Freestyle 50kg       HATH
# 688          CUB      W  Wrestling  Women's Freestyle 50kg       HATH
# 689          JPN      W  Wrestling  Women's Freestyle 50kg       HATH
# 690          CHN      W  Wrestling  Women's Freestyle 50kg       HATH
#
#                                              url_event     code
# 686  /en/paris-2024/results/wrestling/men-s-greco-r...  1566601
# ...

# %%
# renombrar el nombre de una columna
df.rename(columns={'medal_type':'tipo_medalla'})
# Out:
#      tipo_medalla  medal_code  medal_date                    name  \
# 0      Gold Medal           1  2024-07-27         Remco EVENEPOEL
# 1    Silver Medal           2  2024-07-27           Filippo GANNA
# 2    Bronze Medal           3  2024-07-27           Wout van AERT
# 3      Gold Medal           1  2024-07-27             Grace BROWN
# 4    Silver Medal           2  2024-07-27          Anna HENDERSON
# ..            ...         ...         ...                     ...
# 686  Bronze Medal           3  2024-08-07       Uzur DZHUZUPBEKOV
# 687    Gold Medal           1  2024-08-07   Sarah Ann HILDEBRANDT
# 688  Silver Medal           2  2024-08-07  Yusneylis GUZMAN LOPEZ
# 689  Bronze Medal           3  2024-08-07              SUSAKI Yui
# 690  Bronze Medal           3  2024-08-07               FENG Ziqi
#
#     country_code gender    discipline                          event  \
# 0            BEL      M  Cycling Road    Men's Individual Time Trial
# ...

# %%
#ubicarnos en cierta posición del dataframe

df.iloc[1,6]
# Out:
# 'Cycling Road'

# %%
df.loc[4, 'event']
# Out:
# "Women's Individual Time Trial"

# %%
#ubicarnos en cierta posición del dataframe con nombres

df.loc[3, ['name','discipline']]
# Out:
# name           Grace BROWN
# discipline    Cycling Road
# Name: 3, dtype: object

# %% [markdown]
# ## librería matplot.lib

# %%
df = pd.read_csv("MEDALLERO_OLIMPICO_2024.csv", encoding='latin1')

# %%
df
# Out:
#      num             País  Oro  Plata  Bronce  Total
# 0      1   Estados Unidos   27     35      32     94
# 1      2            China   25     23      17     65
# 2      3        Australia   18     12      11     41
# 3      4          Francia   13     17      21     51
# 4      5      Reino Unido   12     17      20     49
# ..   ...              ...  ...    ...     ...    ...
# 99   100  Costa de Marfil    0      0       0      0
# 100  101            Ghana    0      0       0      0
# 101  102            Siria    0      0       0      0
# 102  103     Burkina Faso    0      0       0      0
# 103  104         Botswana    0      0       0      0
#
# [104 rows x 6 columns]

# %%
import matplotlib.pyplot as plt  #importamos la librería

# %%
var_total_oro = (df.Oro >=15)

#(df.Oro >=9) & (df.Plata >20)

df[var_total_oro]
# Out:
#    num            País  Oro  Plata  Bronce  Total
# 0    1  Estados Unidos   27     35      32     94
# 1    2           China   25     23      17     65
# 2    3       Australia   18     12      11     41

# %%
x=df[var_total_oro].País 
y=df[var_total_oro].Oro

plt.plot(x,y) #crear y visualizar la gráfica
#plt.legend() #mostrar las leyendas
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
var_total_medallas = (df.Total >=15)

#(df.Oro >=9) & (df.Plata >20)

df[var_total_medallas]
# Out:
#     num            País  Oro  Plata  Bronce  Total
# 0     1  Estados Unidos   27     35      32     94
# 1     2           China   25     23      17     65
# 2     3       Australia   18     12      11     41
# 3     4         Francia   13     17      21     51
# 4     5     Reino Unido   12     17      20     49
# 5     6   Corea del Sur   12      8       7     27
# 6     7           Japón   12      6      13     31
# 7     8          Italia    9     10       8     27
# 8     9    Países Bajos    9      5       6     20
# 9    10        Alemania    8      5       5     18
# 10   11          Canadá    6      4       9     19

# %%
type(var_total_medallas)
# Out:
# pandas.core.series.Series

# %%
x=df[var_total_medallas].País
y=df[var_total_medallas].Total

plt.barh(x,y)
plt.show()

# %%
fig = plt.figure(figsize = (10,3))

x=df[var_total_medallas].País
y=df[var_total_medallas].Total

plt.barh(x,y)
#plt.barh(x,y, color='tab:purple')
#plt.barh(x,y, color='tab:green')

plt.xlabel('Total de medallas')
plt.ylabel('Países')
plt.title('Total de Medallas Olimpiadas 2024')
plt.show()

# %%
var_topNorteAmerica = (df.País.isin(['Estados Unidos','México','Canadá']))

df[var_topNorteAmerica]
# Out:
#     num            País  Oro  Plata  Bronce  Total
# 0     1  Estados Unidos   27     35      32     94
# 10   11          Canadá    6      4       9     19
# 55   56          México    0      2       1      3

# %%
fig = plt.figure(figsize = (10,5))

x=df[var_topNorteAmerica].País
y=df[var_topNorteAmerica].Total

plt.pie(y, labels=x,autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %%
#instalar librería opendatasets
pip install opendatasets
# Out:
# ...
#      ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/82.7 kB 330.3 kB/s eta 0:00:01
#      ------------------ ------------------- 41.0/82.7 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 82.7/82.7 kB 579.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105795 sha256=6e28237c4af7278819fbcd08c39e62504072211a00e22d40fa450635aca6baf7
#   Stored in directory: c:\users\xideral\appdata\local\pip\cache\wheels\46\d2\26\84d0a1acdb9c6baccf7d28cf06962ec80529fe1ad938489983
# Successfully built kaggle
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importar librería a nuestro entorno
import opendatasets as od

# %%
import pandas as pdb

# %%
#Librerías de python
# numpy operaciones numéricas con grandes cantidades de datos
# analizar datasets, trabaja con conjuto de datos, filas y columnas, es el Excel de Python
# matplotlib visualizar datos

#Machile learning

# %%
lista_3=[900,2,3,4500,1,8]

lista_3.sort()

print(lista_3)
# Out:
# [1, 2, 3, 8, 900, 4500]

# %%
#lectura de archivo por línea ---NO
with open(var_archivo1) as leer_archivo:
    info_archivo = leer_archivo.read()
    print(info_archivo)

leer_archivo.close()
# Out:
# Saludos a todos
# ya pude
# leer
# el archivo

# %%
# funcion index

cadena='Olimpiadas'

#cadena.index('m',0)
cadena.index('d')
# Out:
# 7

# %%
# Redondeo

print(round(100/3))

print(round(12/7,2))

print(int(round(12/7,2)))
# Out:
# 33
# 1.71
# 1

# %%
import requests
import pandas as pd
import statistics

r = requests.get("https://api.recursospython.com/dollar")
cotizacion = statistics.mean(r.json().values())

print(cotizacion)

def dolar_a_peso(precio_en_usd):
    return precio_en_usd * cotizacion

excel = pd.read_excel("productos.xlsx")
excel["Precio en pesos"] = excel["Precio en dólares"].apply(dolar_a_peso)
excel.to_excel("productos_pesificados.xlsx", index=False)

# %%
Mes_actual = "Tacos"
if comida_preferida == "Tacos":
	print("Te gustan los Tacos")
elif comida_preferida == "Pizza":
	print("Te gusta la Pizza")
elif comida_preferida == "Hamburguesa":
	print("Te gustan las hamburguesas")
else:
	print("Te gusta otra comida")

# %%
Soluciones a las Prácticas del Día 1
Soluciones a las Prácticas del Día 1


Antes de dar por finalizadas las prácticas del día de hoy y pasar al proyecto, te comparto las posibles soluciones para cada una de las prácticas que fueron propuestas el día de hoy, en caso de que hayas tenido alguna dificultad para terminarlas.

¡Ten en cuenta que estas soluciones no son únicas! Si has arribado por otro camino a un código que arroja un resultado correcto en PyCharm o tu editor de código de preferencia, quiero que sepas que has hecho un buen trabajo (no siempre pueden contemplarse todos los casos a la hora de evaluar una tarea).

Práctica Print 1

print("Me encanta estudiar Python")

Práctica Print 2

print('Estudiar con "Python Total" es super divertido')

Práctica Print 3

print(5+550)

Práctica String 1

print("Línea 1\nLínea 2\nLínea 3")

Práctica String 2

print("A\tB\tC\nD\tE\tF\nG\tH\tI")

Práctica String 3

print("Barra Normal: /\nBarra Invertida: \\")

Práctica Input 1

print(input("¿Qué estás estudiando?"))

Práctica Input 2

print(input("¿En qué país vives?"))

Práctica Input 3

print(input("Escribe tu nombre:")+" "+input("Escribe tu apellido:"))



#Recuerda que si tienes alguna duda que aún no quede resuelta, tienes a tu disposición el espacio de Preguntas y Respuestas.

#Te veo en el proyecto!

# %%
print("Barra Normal: /\nBarra Invertida: \\")
# Out:
# Barra Normal: /
# Barra Invertida: \

# %%
print("Línea 1\nLínea 2\nLínea 3")
# Out:
# Línea 1
# Línea 2
# Línea 3

# %% [markdown]
# blue|red|green|pink|yellow

# %% [markdown]
# $\sqrt{k}$

# %% [markdown]
# **&#64;**
